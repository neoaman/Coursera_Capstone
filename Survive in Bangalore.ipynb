# %% [markdown]
# # My Capstone Project

# %% [markdown]
# <hr>

# %% [markdown]
# ## __Project Name__ :
# # Survive in Bangalore

# %% [markdown]
# <hr>

# %% [markdown]
# ### In my project I am going to share you some idea about exploring new places using foursquare api.
# #### Suppose I have completed my Post Graduation in Statistics from Bhubaneswar, Odisha and moving to Bangalore for higher studies in Data science. Although you have much idea to survive in new places, asking to neighouberhood friends and your instructors also room-mate. But what if you havenot been to Bangalore prior to this, also you dont have bike to explore the new place. So dont worry about it, we have our friendly app foursquare to help us in our journey.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Step: 1
# ### Search for Nearby ATM and PG ?
# <hr>

# %% [markdown]
# ### Lets Begin our project by Importing Required packages

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
! pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/lib/python3.6/site-packages (1.11.0)
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'DIFB4NBGW2Q52A52H00ZYIODEVAQQAVE1KY5UWIABBS2VGDB' # your Foursquare ID
CLIENT_SECRET = 'ZZ5WA24J5JDKIUUN2RQGJF1EWHPXRPKABLFFUY1YCH23SICB' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DIFB4NBGW2Q52A52H00ZYIODEVAQQAVE1KY5UWIABBS2VGDB
# CLIENT_SECRET:ZZ5WA24J5JDKIUUN2RQGJF1EWHPXRPKABLFFUY1YCH23SICB

# %%
address = '1st Stage, BTM Layout'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 12.9171879 77.6088051

# %% [markdown]
# #### The Place where we are going to stay is in "BTM Layout" so lets set our Location and set the radious of 2 km

# %%
#search_query = 'Indian,solutions'
search_query = 'atm,pg'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# atm,pg .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DIFB4NBGW2Q52A52H00ZYIODEVAQQAVE1KY5UWIABBS2VGDB&client_secret=ZZ5WA24J5JDKIUUN2RQGJF1EWHPXRPKABLFFUY1YCH23SICB&ll=12.9171879,77.6088051&v=20180604&query=atm,pg&radius=2000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d279cc389b06a002c9553d5'},
#  'response': {'venues': [{'id': '4fb283a27bebc1fb6507015d',
#     'name': 'Kotak Mahindra Bank - ATM',
#     'location': {'address': 'Shop No. 5 Ground Floor “Akshay Complex No. 1” PID No. 65-27-1 16th Main Road B.T.M. 2nd Stage 1st Phase Extension',
#      'crossStreet': '16th Main Udupi Garden',
#      'lat': 12.91612609915097,
#      'lng': 77.6098762624273,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.91612609915097,
#        'lng': 77.6098762624273}],
#      'distance': 165,
#      'postalCode': '560076',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Shop No. 5 Ground Floor “Akshay Complex No. 1” PID No. 65-27-1 16th Main Road B.T.M. 2nd Stage 1st Phase Extension (16th Main Udupi Garden)',
#       'Bangalore 560076',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '4fc377c4e4b06a3981d13063',
#     'name': 'Paying Guest Hostel(PG)',
#     'location': {'address': 'Maruthi Layout',
#      'crossStreet': '3rd Main',
#      'lat': 12.920381546020508,
#      'lng': 77.60798645019531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.920381546020508,
#        'lng': 77.60798645019531}],
#      'distance': 366,
#      'cc': 'IN',
#      'city': 'Banglore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Maruthi Layout (3rd Main)',
#       'Banglore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '539f47ff498e0d932ea5ddd8',
#     'name': 'SNS PG',
#     'location': {'lat': 12.919814109802246,
#      'lng': 77.61770629882812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.919814109802246,
#        'lng': 77.61770629882812}],
#      'distance': 1009,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '5c2b49aaacc5f5002c581306',
#     'name': 'Axis Bank ATM',
#     'location': {'address': 'No 1214, Near Dominos Pizza Road',
#      'crossStreet': 'Btm Layout',
#      'lat': 12.914979934692,
#      'lng': 77.610061645508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.914979934692,
#        'lng': 77.610061645508}],
#      'distance': 281,
#      'postalCode': '560029',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['No 1214, Near Dominos Pizza Road (Btm Layout)',
#       'Bangalore 560029',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b56',
#       'name': 'ATM',
#       'pluralName': 'ATMs',
#       'shortName': 'ATM',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '56d69117498e82920b369d03',
#     'name': 'Life Style PG',
#     'location': {'lat': 12.917783,
#      'lng': 77.6137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.917783,
#        'lng': 77.6137}],
#      'distance': 535,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '557412e2498e17b865efe712',
#     'name': 'SSSB PG',
#     'location': {'address': '#16, Venkateswara Layout',
#      'crossStreet': '1st Cross',
#      'lat': 12.93396049325498,
#      'lng': 77.6074088299901,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.93396049325498,
#        'lng': 77.6074088299901}],
#      'distance': 1873,
#      'cc': 'IN',
#      'city': 'S.G.Palaya, Banglaore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['#16, Venkateswara Layout (1st Cross)',
#       'S.G.Palaya, Banglaore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '518490e0498edeecfbbaadfc',
#     'name': 'Allahabad Bank Atm',
#     'location': {'lat': 12.913870894443166,
#      'lng': 77.61043016840728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.913870894443166,
#        'lng': 77.61043016840728}],
#      'distance': 409,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '500d8084e4b099ec37c4610f',
#     'name': 'Kalasa Arcade Mens PG',
#     'location': {'address': '19th Cross, 7 Main',
#      'lat': 12.90702698415509,
#      'lng': 77.60768858694946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.90702698415509,
#        'lng': 77.60768858694946}],
#      'distance': 1137,
#      'postalCode': '560076',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['19th Cross, 7 Main',
#       'Bangalore 560076',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '5221dde4498e569a0b14fbd3',
#     'name': 'sln pg',
#     'location': {'lat': 12.92279052734375,
#      'lng': 77.61263275146484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.92279052734375,
#        'lng': 77.61263275146484}],
#      'distance': 749,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '5880f589084be55c00a77fdb',
#     'name': 'Shri Sai Bhavani PG',
#     'location': {'address': '#61/1',
#      'crossStreet': '4th Main, Jai Bheema Nagar, BTM Layout 1st Stage',
#      'lat': 12.9185,
#      'lng': 77.615463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.9185,
#        'lng': 77.615463}],
#      'distance': 737,
#      'postalCode': '560068',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['#61/1 (4th Main, Jai Bheema Nagar, BTM Layout 1st Stage)',
#       'Bangalore 560068',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '574b231c498e18aea0804c05',
#     'name': 'Delight Pg For ladies',
#     'location': {'lat': 12.923537,
#      'lng': 77.615398,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.923537,
#        'lng': 77.615398}],
#      'distance': 1005,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '53a6d2d0498e56d9917a0d8b',
#     'name': 'Emirates pg',
#     'location': {'address': 'Tavarekere',
#      'lat': 12.923989,
#      'lng': 77.609385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.923989,
#        'lng': 77.609385}],
#      'distance': 759,
#      'postalCode': '560029',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Tavarekere',
#       'Bangalore 560029',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '5625bf3a498e48241b098cbd',
#     'name': 'Sri lakshmi Venkateshwara Ladies Pg',
#     'location': {'address': 'Plot No. 16 , 30th Main ,',
#      'crossStreet': '1st Cross, Kuvempu Nagar, BTM 2nd Stage',
#      'lat': 12.915089430518991,
#      'lng': 77.61531449417306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.915089430518991,
#        'lng': 77.61531449417306}],
#      'distance': 743,
#      'postalCode': '560076',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Plot No. 16 , 30th Main , (1st Cross, Kuvempu Nagar, BTM 2nd Stage)',
#       'Bangalore 560076',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '4e5106f7b0fb088f3c31502e',
#     'name': 'PG for men next to kairali',
#     'location': {'crossStreet': 'Krishna nagar industrial layout',
#      'lat': 12.934849598173528,
#      'lng': 77.60755430369561,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.934849598173528,
#        'lng': 77.60755430369561}],
#      'distance': 1970,
#      'postalCode': '560029',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['Krishna nagar industrial layout',
#       'Bangalore 560029',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '4f68bfa8e4b05e22658fde29',
#     'name': 'P.J Philip PG',
#     'location': {'address': '6th cross, Taverkare',
#      'lat': 12.927076386808325,
#      'lng': 77.60917688230123,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.927076386808325,
#        'lng': 77.60917688230123}],
#      'distance': 1101,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['6th cross, Taverkare', 'India']},
#     'categories': [],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '5303a0d411d2eac30b632836',
#     'name': 'HDFC Bank ATM',
#     'location': {'address': '# 1224, 17Th Main, 8Th Cross, Btm 1St Stage Maruthinagar Main Road Near Gangotri Bar & Restarunt',
#      'lat': 12.91984,
#      'lng': 77.611248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.91984,
#        'lng': 77.611248}],
#      'distance': 396,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['# 1224, 17Th Main, 8Th Cross, Btm 1St Stage Maruthinagar Main Road Near Gangotri Bar & Restarunt',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '525acb41498e3976736b12f9',
#     'name': 'Raja rajeshwari pg',
#     'location': {'address': 'btm,madiwala',
#      'lat': 12.920049614158394,
#      'lng': 77.6157452893749,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.920049614158394,
#        'lng': 77.6157452893749}],
#      'distance': 817,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['btm,madiwala', 'Bangalore', 'Karnātaka', 'India']},
#     'categories': [],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '53889843498e264f18c0be2c',
#     'name': 'Brundhavan PG',
#     'location': {'lat': 12.911089897155762,
#      'lng': 77.60335540771484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.911089897155762,
#        'lng': 77.60335540771484}],
#      'distance': 900,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '50cc7f6ce4b0881a7314b7a5',
#     'name': 'Canara Bank ATM',
#     'location': {'lat': 12.914125217243761,
#      'lng': 77.61078824759186,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.914125217243761,
#        'lng': 77.61078824759186}],
#      'distance': 403,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '4e7586c27d8b9176031d6de9',
#     'name': 'Sbi Atm',
#     'location': {'lat': 12.91383925,
#      'lng': 77.60832966,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.91383925,
#        'lng': 77.60832966}],
#      'distance': 376,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '5303a0df11d2eac30b648457',
#     'name': 'HDFC Bank ATM',
#     'location': {'address': 'No, 397, 7Th Cross, 9Th Main, Mico Layout, Btm 2Nd Stage. Behind Shopers Stop',
#      'lat': 12.913606,
#      'lng': 77.607388,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.913606,
#        'lng': 77.607388}],
#      'distance': 427,
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['No, 397, 7Th Cross, 9Th Main, Mico Layout, Btm 2Nd Stage. Behind Shopers Stop',
#       'Bangalore',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '52d7da58498e9d11a54660c6',
#     'name': 'SLV Gents PG',
#     'location': {'lat': 12.923093795776367,
#      'lng': 77.61490631103516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.923093795776367,
#        'lng': 77.61490631103516}],
#      'distance': 932,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '50604726e4b0d9a2f221902c',
#     'name': "Mohan Reddy's Pg",
#     'location': {'address': 'Sg Palya',
#      'crossStreet': '1st Cross Street',
#      'lat': 12.933813268481702,
#      'lng': 77.60738010156922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.933813268481702,
#        'lng': 77.60738010156922}],
#      'distance': 1857,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Sg Palya (1st Cross Street)', 'India']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '4fc58935e4b0035511cfad38',
#     'name': 'Chennakeshava PG',
#     'location': {'lat': 12.920083045959473,
#      'lng': 77.61727905273438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.920083045959473,
#        'lng': 77.61727905273438}],
#      'distance': 974,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '4c1fa330eac020a1ee644bc2',
#     'name': 'HSBC ATM',
#     'location': {'address': 'BTM Layout',
#      'lat': 12.913409,
#      'lng': 77.606892,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.913409,
#        'lng': 77.606892}],
#      'distance': 469,
#      'postalCode': '560029',
#      'cc': 'IN',
#      'city': 'Bangalore',
#      'state': 'Karnātaka',
#      'country': 'India',
#      'formattedAddress': ['BTM Layout',
#       'Bangalore 560029',
#       'Karnātaka',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '52f7b43d11d28d688c3ab23f',
#     'name': 'Svs pg',
#     'location': {'lat': 12.924224389717,
#      'lng': 77.6151058170944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.924224389717,
#        'lng': 77.6151058170944}],
#      'distance': 1039,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '530c14ad498e6f99f1a0ed8a',
#     'name': 'new paradise Mens pg',
#     'location': {'lat': 12.925306217047908,
#      'lng': 77.61303181158154,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.925306217047908,
#        'lng': 77.61303181158154}],
#      'distance': 1013,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '536ee5dc498e6848bddec519',
#     'name': 'Susheela PG',
#     'location': {'lat': 12.909909,
#      'lng': 77.602962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.909909,
#        'lng': 77.602962}],
#      'distance': 1028,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '51460a58e4b02de94e130506',
#     'name': "R.B's PG",
#     'location': {'lat': 12.935534151878214,
#      'lng': 77.61368081427953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 12.935534151878214,
#        'lng': 77.61368081427953}],
#      'distance': 2109,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False},
#    {'id': '4f2fe0d9e4b0b0d0865e516b',
#     'name': 'maharashtra bank atm',
#     'location': {'lat': 12.9133,
#      'lng': 77.6065,
#      'labeledLatLngs': [{'label': 'display', 'lat': 12.9133, 'lng': 77.6065}],
#      'distance': 499,
#      'cc': 'IN',
#      'city': 'banglore',
#      'country': 'India',
#      'formattedAddress': ['banglore', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562877123',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
# 1   [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 2   [{'id': '4bf58dd8d48988d130941735', 'name': 'B...    False
# 3   [{'id': '52f2ab2ebcbc57f1066b8b56', 'name': 'A...    False
# 4   [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 5   [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 6   [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
# 7   [{'id': '4f2a210c4b9023bd5841ed28', 'name': 'H...    False
# 8   [{'id': '5032891291d4c4b30a586d68', 'name': 'A...    False
# 9   [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 10  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 11  [{'id': '5032891291d4c4b30a586d68', 'name': 'A...    False
# 12  [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...    False
# 13  [{'id': '4bf58dd8d48988d1fb931735', 'name': 'M...    False
# 14                                                 []    False
# 15  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
# 16                                                 []    False
# 17  [{'id': '5032891291d4c4b30a586d68', 'name': 'A...    False
# 18  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
# 19  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
# 20  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
# 21  [{'id': '5032891291d4c4b30a586d68', 'name': 'A...    False
# 22  [{'id': '5032891291d4c4b30a586d68', 'name': 'A...    False
# 23  [{'id': '4f2a210c4b9023bd5841ed28', 'name': 'H...    False
# 24  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
# 25                                                 []    False
# 26  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 27  [{'id': '5032891291d4c4b30a586d68', 'name': 'A...    False
# 28  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 29  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
#
#                           id  \
# 0   4fb283a27bebc1fb6507015d
# 1   4fc377c4e4b06a3981d13063
# 2   539f47ff498e0d932ea5ddd8
# 3   5c2b49aaacc5f5002c581306
# 4   56d69117498e82920b369d03
# 5   557412e2498e17b865efe712
# 6   518490e0498edeecfbbaadfc
# 7   500d8084e4b099ec37c4610f
# 8   5221dde4498e569a0b14fbd3
# 9   5880f589084be55c00a77fdb
# 10  574b231c498e18aea0804c05
# 11  53a6d2d0498e56d9917a0d8b
# 12  5625bf3a498e48241b098cbd
# 13  4e5106f7b0fb088f3c31502e
# 14  4f68bfa8e4b05e22658fde29
# 15  5303a0d411d2eac30b632836
# 16  525acb41498e3976736b12f9
# 17  53889843498e264f18c0be2c
# 18  50cc7f6ce4b0881a7314b7a5
# 19  4e7586c27d8b9176031d6de9
# 20  5303a0df11d2eac30b648457
# 21  52d7da58498e9d11a54660c6
# 22  50604726e4b0d9a2f221902c
# 23  4fc58935e4b0035511cfad38
# 24  4c1fa330eac020a1ee644bc2
# 25  52f7b43d11d28d688c3ab23f
# 26  530c14ad498e6f99f1a0ed8a
# 27  536ee5dc498e6848bddec519
# 28  51460a58e4b02de94e130506
# 29  4f2fe0d9e4b0b0d0865e516b
#
#                                      location.address location.cc  \
# 0   Shop No. 5 Ground Floor “Akshay Complex No. 1”...          IN
# 1                                      Maruthi Layout          IN
# 2                                                 NaN          IN
# 3                    No 1214, Near Dominos Pizza Road          IN
# 4                                                 NaN          IN
# 5                            #16, Venkateswara Layout          IN
# 6                                                 NaN          IN
# 7                                  19th Cross, 7 Main          IN
# 8                                                 NaN          IN
# 9                                               #61/1          IN
# 10                                                NaN          IN
# 11                                         Tavarekere          IN
# 12                          Plot No. 16 , 30th Main ,          IN
# 13                                                NaN          IN
# 14                               6th cross, Taverkare          IN
# 15  # 1224, 17Th Main, 8Th Cross, Btm 1St Stage Ma...          IN
# 16                                       btm,madiwala          IN
# 17                                                NaN          IN
# 18                                                NaN          IN
# 19                                                NaN          IN
# 20  No, 397, 7Th Cross, 9Th Main, Mico Layout, Btm...          IN
# 21                                                NaN          IN
# 22                                           Sg Palya          IN
# 23                                                NaN          IN
# 24                                         BTM Layout          IN
# 25                                                NaN          IN
# 26                                                NaN          IN
# 27                                                NaN          IN
# 28                                                NaN          IN
# 29                                                NaN          IN
#
#             location.city location.country  \
# 0               Bangalore            India
# 1                Banglore            India
# 2                     NaN            India
# 3               Bangalore            India
# 4                     NaN            India
# 5   S.G.Palaya, Banglaore            India
# 6                     NaN            India
# 7               Bangalore            India
# 8                     NaN            India
# 9               Bangalore            India
# 10                    NaN            India
# 11              Bangalore            India
# 12              Bangalore            India
# 13              Bangalore            India
# 14                    NaN            India
# 15              Bangalore            India
# 16              Bangalore            India
# 17                    NaN            India
# 18                    NaN            India
# 19                    NaN            India
# 20              Bangalore            India
# 21                    NaN            India
# 22                    NaN            India
# 23                    NaN            India
# 24              Bangalore            India
# 25                    NaN            India
# 26                    NaN            India
# 27                    NaN            India
# 28                    NaN            India
# 29               banglore            India
#
#                                 location.crossStreet  location.distance  \
# 0                             16th Main Udupi Garden                165
# 1                                           3rd Main                366
# 2                                                NaN               1009
# 3                                         Btm Layout                281
# 4                                                NaN                535
# 5                                          1st Cross               1873
# 6                                                NaN                409
# 7                                                NaN               1137
# 8                                                NaN                749
# 9   4th Main, Jai Bheema Nagar, BTM Layout 1st Stage                737
# 10                                               NaN               1005
# 11                                               NaN                759
# 12           1st Cross, Kuvempu Nagar, BTM 2nd Stage                743
# 13                   Krishna nagar industrial layout               1970
# 14                                               NaN               1101
# 15                                               NaN                396
# 16                                               NaN                817
# 17                                               NaN                900
# 18                                               NaN                403
# 19                                               NaN                376
# 20                                               NaN                427
# 21                                               NaN                932
# 22                                  1st Cross Street               1857
# 23                                               NaN                974
# 24                                               NaN                469
# 25                                               NaN               1039
# 26                                               NaN               1013
# 27                                               NaN               1028
# 28                                               NaN               2109
# 29                                               NaN                499
#
#                             location.formattedAddress  \
# 0   [Shop No. 5 Ground Floor “Akshay Complex No. 1...
# 1   [Maruthi Layout (3rd Main), Banglore, Karnātak...
# 2                                             [India]
# 3   [No 1214, Near Dominos Pizza Road (Btm Layout)...
# 4                                             [India]
# 5   [#16, Venkateswara Layout (1st Cross), S.G.Pal...
# 6                                             [India]
# 7   [19th Cross, 7 Main, Bangalore 560076, Karnāta...
# 8                                             [India]
# 9   [#61/1 (4th Main, Jai Bheema Nagar, BTM Layout...
# 10                                            [India]
# 11   [Tavarekere, Bangalore 560029, Karnātaka, India]
# 12  [Plot No. 16 , 30th Main , (1st Cross, Kuvempu...
# 13  [Krishna nagar industrial layout, Bangalore 56...
# 14                      [6th cross, Taverkare, India]
# 15  [# 1224, 17Th Main, 8Th Cross, Btm 1St Stage M...
# 16        [btm,madiwala, Bangalore, Karnātaka, India]
# 17                                            [India]
# 18                                            [India]
# 19                                            [India]
# 20  [No, 397, 7Th Cross, 9Th Main, Mico Layout, Bt...
# 21                                            [India]
# 22               [Sg Palya (1st Cross Street), India]
# 23                                            [India]
# 24   [BTM Layout, Bangalore 560029, Karnātaka, India]
# 25                                            [India]
# 26                                            [India]
# 27                                            [India]
# 28                                            [India]
# 29                                  [banglore, India]
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 12.91612609915097...     12.916126
# 1   [{'label': 'display', 'lat': 12.92038154602050...     12.920382
# 2   [{'label': 'display', 'lat': 12.91981410980224...     12.919814
# 3   [{'label': 'display', 'lat': 12.914979934692, ...     12.914980
# 4   [{'label': 'display', 'lat': 12.917783, 'lng':...     12.917783
# 5   [{'label': 'display', 'lat': 12.93396049325498...     12.933960
# 6   [{'label': 'display', 'lat': 12.91387089444316...     12.913871
# 7   [{'label': 'display', 'lat': 12.90702698415509...     12.907027
# 8   [{'label': 'display', 'lat': 12.92279052734375...     12.922791
# 9   [{'label': 'display', 'lat': 12.9185, 'lng': 7...     12.918500
# 10  [{'label': 'display', 'lat': 12.923537, 'lng':...     12.923537
# 11  [{'label': 'display', 'lat': 12.923989, 'lng':...     12.923989
# 12  [{'label': 'display', 'lat': 12.91508943051899...     12.915089
# 13  [{'label': 'display', 'lat': 12.93484959817352...     12.934850
# 14  [{'label': 'display', 'lat': 12.92707638680832...     12.927076
# 15  [{'label': 'display', 'lat': 12.91984, 'lng': ...     12.919840
# 16  [{'label': 'display', 'lat': 12.92004961415839...     12.920050
# 17  [{'label': 'display', 'lat': 12.91108989715576...     12.911090
# 18  [{'label': 'display', 'lat': 12.91412521724376...     12.914125
# 19  [{'label': 'display', 'lat': 12.91383925, 'lng...     12.913839
# 20  [{'label': 'display', 'lat': 12.913606, 'lng':...     12.913606
# 21  [{'label': 'display', 'lat': 12.92309379577636...     12.923094
# 22  [{'label': 'display', 'lat': 12.93381326848170...     12.933813
# 23  [{'label': 'display', 'lat': 12.92008304595947...     12.920083
# 24  [{'label': 'display', 'lat': 12.913409, 'lng':...     12.913409
# 25  [{'label': 'display', 'lat': 12.924224389717, ...     12.924224
# 26  [{'label': 'display', 'lat': 12.92530621704790...     12.925306
# 27  [{'label': 'display', 'lat': 12.909909, 'lng':...     12.909909
# 28  [{'label': 'display', 'lat': 12.93553415187821...     12.935534
# 29  [{'label': 'display', 'lat': 12.9133, 'lng': 7...     12.913300
#
#     location.lng location.postalCode location.state  \
# 0      77.609876              560076      Karnātaka
# 1      77.607986                 NaN      Karnātaka
# 2      77.617706                 NaN            NaN
# 3      77.610062              560029      Karnātaka
# 4      77.613700                 NaN            NaN
# 5      77.607409                 NaN      Karnātaka
# 6      77.610430                 NaN            NaN
# 7      77.607689              560076      Karnātaka
# 8      77.612633                 NaN            NaN
# 9      77.615463              560068      Karnātaka
# 10     77.615398                 NaN            NaN
# 11     77.609385              560029      Karnātaka
# 12     77.615314              560076      Karnātaka
# 13     77.607554              560029      Karnātaka
# 14     77.609177                 NaN            NaN
# 15     77.611248                 NaN      Karnātaka
# 16     77.615745                 NaN      Karnātaka
# 17     77.603355                 NaN            NaN
# 18     77.610788                 NaN            NaN
# 19     77.608330                 NaN            NaN
# 20     77.607388                 NaN      Karnātaka
# 21     77.614906                 NaN            NaN
# 22     77.607380                 NaN            NaN
# 23     77.617279                 NaN            NaN
# 24     77.606892              560029      Karnātaka
# 25     77.615106                 NaN            NaN
# 26     77.613032                 NaN            NaN
# 27     77.602962                 NaN            NaN
# 28     77.613681                 NaN            NaN
# 29     77.606500                 NaN            NaN
#
#                                    name    referralId
# 0             Kotak Mahindra Bank - ATM  v-1562877123
# 1               Paying Guest Hostel(PG)  v-1562877123
# 2                                SNS PG  v-1562877123
# 3                         Axis Bank ATM  v-1562877123
# 4                         Life Style PG  v-1562877123
# 5                               SSSB PG  v-1562877123
# 6                    Allahabad Bank Atm  v-1562877123
# 7                 Kalasa Arcade Mens PG  v-1562877123
# 8                                sln pg  v-1562877123
# 9                   Shri Sai Bhavani PG  v-1562877123
# 10                Delight Pg For ladies  v-1562877123
# 11                          Emirates pg  v-1562877123
# 12  Sri lakshmi Venkateshwara Ladies Pg  v-1562877123
# 13           PG for men next to kairali  v-1562877123
# 14                        P.J Philip PG  v-1562877123
# 15                        HDFC Bank ATM  v-1562877123
# 16                   Raja rajeshwari pg  v-1562877123
# 17                        Brundhavan PG  v-1562877123
# 18                      Canara Bank ATM  v-1562877123
# 19                              Sbi Atm  v-1562877123
# 20                        HDFC Bank ATM  v-1562877123
# 21                         SLV Gents PG  v-1562877123
# 22                     Mohan Reddy's Pg  v-1562877123
# 23                     Chennakeshava PG  v-1562877123
# 24                             HSBC ATM  v-1562877123
# 25                               Svs pg  v-1562877123
# 26                 new paradise Mens pg  v-1562877123
# 27                          Susheela PG  v-1562877123
# 28                             R.B's PG  v-1562877123
# 29                 maharashtra bank atm  v-1562877123

# %% [markdown]
# ### keep only columns that include venue name, and anything that is associated with location

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %%
dataframe_filtered.categories[0][0]['name']
# Out:
# 'Bank'

# %% [markdown]
# ### Filter the categories column

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# %%
dataframe_filtered[['location.lat','location.lng']].head()
# Out:
#    location.lat  location.lng
# 0     12.916126     77.609876
# 1     12.920382     77.607986
# 2     12.919814     77.617706
# 3     12.914980     77.610062
# 4     12.917783     77.613700

# %%
dataframe_filtered.categories.unique()
# Out:
# array(['Bank', 'Residential Building (Apartment / Condo)', 'Building',
#        'ATM', 'Housing Development', 'Assisted Living', 'Hostel', 'Motel',
#        None], dtype=object)

# %% [markdown]
# #### Here we get our Data Frame to work with.

# %%
dataframe_filtered.head(2)
# Out:
#                         name                                categories  \
# 0  Kotak Mahindra Bank - ATM                                      Bank
# 1    Paying Guest Hostel(PG)  Residential Building (Apartment / Condo)
#
#                                     location.address location.cc  \
# 0  Shop No. 5 Ground Floor “Akshay Complex No. 1”...          IN
# 1                                     Maruthi Layout          IN
#
#   location.city location.country    location.crossStreet  location.distance  \
# 0     Bangalore            India  16th Main Udupi Garden                165
# 1      Banglore            India                3rd Main                366
#
#                            location.formattedAddress  \
# 0  [Shop No. 5 Ground Floor “Akshay Complex No. 1...
# 1  [Maruthi Layout (3rd Main), Banglore, Karnātak...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 12.91612609915097...     12.916126
# 1  [{'label': 'display', 'lat': 12.92038154602050...     12.920382
#
#    location.lng location.postalCode location.state                        id
# 0     77.609876              560076      Karnātaka  4fb283a27bebc1fb6507015d
# 1     77.607986                 NaN      Karnātaka  4fc377c4e4b06a3981d13063

# %%
import folium

# %% [markdown]
# #### Now Lets Plot the Map with required data Points

# %%
def placecol(i):
    switch={
        'Bank':'blue',
        'Residential Building (Apartment / Condo)':'green',
        'Assisted Living':'green', 
        'ATM':'lightblue', 
        'Hostel':'orange', 
        None:'green', 
        'Housing Development':'lightgreen',
        'Building':'green',
    }
    return switch.get(i)

# %%
df=dataframe_filtered

# %%
Bangaluru = folium.Map(location=[latitude,longitude],zoom_start=15)
loc = folium.map.FeatureGroup()
for lt,ln,cat,nam in zip(df['location.lat'],df['location.lng'],df['categories'],df.name):
    loc.add_child(
        folium.CircleMarker(
            location=[lt,ln],
            color=placecol(cat),
            radious=5,
            fill=True,
            fill_color=placecol(cat),
            fill_opacity=0.6,
            #popup=nam,
            
        )
    )
Bangaluru.add_child(loc)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Here is the Map Showing :
# . Blue marks with ATM
# . Green marks with PG
# . Yellow Marks are with

# %% [markdown]
# <hr>
#
# <hr>

# %% [markdown]
# ## Step 2:
# ### Next Step is to See the Reviews of those PG, Where to Stay ?
#
# <hr>

# %%
df_pgid=dataframe_filtered.loc[
                   dataframe_filtered.name.str.contains('PG') | 
                   dataframe_filtered.name.str.contains('pg') | 
                   dataframe_filtered.name.str.contains('Pg'),['name','id']]

# %%
df_pgid.count()
# Out:
# name    21
# id      21
# dtype: int64

# %%
# For PG 1
venue_id = '50604726e4b0d9a2f221902c' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/50604726e4b0d9a2f221902c?client_id=DIFB4NBGW2Q52A52H00ZYIODEVAQQAVE1KY5UWIABBS2VGDB&client_secret=ZZ5WA24J5JDKIUUN2RQGJF1EWHPXRPKABLFFUY1YCH23SICB&v=20180604'

# %%
result = requests.get(url).json()
result['response']['venue'].keys()
# Out:
# {'meta': {'code': 429,
#   'errorType': 'quota_exceeded',
#   'errorDetail': 'Quota exceeded',
#   'requestId': '5d279e77e8f92800230b09b3'},
#  'response': {}}

# %%
try:
    print(result['response']['venue']['likes']['count'])
except:
    print('This venue has not been rated yet.')

# %%
for i,j in zip(df_pgid.id,df_pgid.name) :
    venue_id = i 
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    A=result['response']['venue']['likes']['count']
    print(A,)

# %%
venue_id = '50604726e4b0d9a2f221902c'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
result = requests.get(url).json()
result['response']['venue']['likes']['count']

# %% [markdown]
# #### Next Step is to See the Reviews of those PG, Where to Stay ?
